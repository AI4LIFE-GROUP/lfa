# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

import numpy as np

from functions_model_training import LinearRegressionNN, DatasetFromCSV, train, test

# %% [markdown]
# # train model

# %% [markdown]
# ### linear regression setup

# %%
#linear regression setup

#dataset: predict wine type, last column in csv
test_size = 0.20
train_str = int((1-test_size)*100)
test_str = int(test_size*100)
dataset_name = 'who'

task = 'regr'
train_ds = DatasetFromCSV(filepath=f'../data/clean/{dataset_name}-clean-train{train_str}-normalized.csv', target_idx=-1)
test_ds = DatasetFromCSV(filepath=f'../data/clean/{dataset_name}-clean-test{test_str}-normalized.csv', target_idx=-1)

#dataloader
batch_size=64
train_dl = DataLoader(dataset=train_ds, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(dataset=test_ds, batch_size=batch_size, shuffle=True)

#model
model = LinearRegressionNN(input_dim=train_ds.X.shape[1])

#training parameters
n_epochs = 100
criterion = nn.MSELoss()
learning_rate = 0.2
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)
seed = 12345

#model description to add to name of checkpoint file
data_descrip=dataset_name
model_descrip='linear'

# %% [markdown]
# ### training loop

# %%
#train model
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)

for epoch in range(0, n_epochs):
    torch.manual_seed(seed)
    train(epoch, model, train_dl, device, optimizer, criterion, task)
    test(epoch, model, test_dl, device, criterion, data_descrip, model_descrip, task)
    scheduler.step()
# Out:
# --------------------
# Epoch 0
# train loss (loss per point): 0.001586205400130216
# test loss (loss per point): 0.0002564965188186489
# ***saved checkpoint
# --------------------
# Epoch 1
# train loss (loss per point): 0.00020723262960289387
# test loss (loss per point): 0.00015566485290903422
# ***saved checkpoint
# --------------------
# Epoch 2
# train loss (loss per point): 0.00015243774656444154
# test loss (loss per point): 0.00012711430646377762
# ***saved checkpoint
# --------------------
# Epoch 3
# train loss (loss per point): 0.00013125312227280217
# test loss (loss per point): 0.00011427641678348082
# ***saved checkpoint
# --------------------
# Epoch 4
# train loss (loss per point): 0.00011995097552921543
# test loss (loss per point): 0.00010740183029311146
# ***saved checkpoint
# --------------------
# Epoch 5
# train loss (loss per point): 0.00011317439129615718
# test loss (loss per point): 0.00010333442941726166
# ***saved checkpoint
# --------------------
# Epoch 6
# train loss (loss per point): 0.00010883279996825026
# test loss (loss per point): 0.0001007682199551895
# ***saved checkpoint
# --------------------
# Epoch 7
# train loss (loss per point): 0.0001059205368398986
# test loss (loss per point): 9.907489613991002e-05
# ***saved checkpoint
# --------------------
# Epoch 8
# train loss (loss per point): 0.00010389535598694644
# test loss (loss per point): 9.791978292775397e-05
# ***saved checkpoint
# --------------------
# Epoch 9
# train loss (loss per point): 0.00010244284449343352
# test loss (loss per point): 9.711165904529951e-05
# ***saved checkpoint
# --------------------
# Epoch 10
# train loss (loss per point): 0.00010137120856249586
# test loss (loss per point): 9.653580154856148e-05
# ***saved checkpoint
# --------------------
# Epoch 11
# train loss (loss per point): 0.00010055919197645593
# test loss (loss per point): 9.612087516722326e-05
# ***saved checkpoint
# --------------------
# Epoch 12
# train loss (loss per point): 9.992798948858647e-05
# test loss (loss per point): 9.582138408076803e-05
# ***saved checkpoint
# --------------------
# Epoch 13
# train loss (loss per point): 9.942521549206465e-05
# test loss (loss per point): 9.560760951657989e-05
# ***saved checkpoint
# --------------------
# Epoch 14
# train loss (loss per point): 9.901544861891803e-05
# test loss (loss per point): 9.545977235309222e-05
# ***saved checkpoint
# --------------------
# Epoch 15
# train loss (loss per point): 9.867424918140503e-05
# test loss (loss per point): 9.536448126456061e-05
# ***saved checkpoint
# --------------------
# Epoch 16
# train loss (loss per point): 9.838455812411105e-05
# test loss (loss per point): 9.531243252853046e-05
# ***saved checkpoint
# --------------------
# Epoch 17
# train loss (loss per point): 9.813420801482937e-05
# test loss (loss per point): 9.529707520934088e-05
# ***saved checkpoint
# --------------------
# Epoch 18
# train loss (loss per point): 9.791448008903164e-05
# test loss (loss per point): 9.531365132567529e-05
# --------------------
# Epoch 19
# train loss (loss per point): 9.771891314774118e-05
# test loss (loss per point): 9.535860862633606e-05
# --------------------
# Epoch 20
# train loss (loss per point): 9.754276596643823e-05
# test loss (loss per point): 9.542922323037471e-05
# --------------------
# Epoch 21
# train loss (loss per point): 9.738243987506374e-05
# test loss (loss per point): 9.552330660893499e-05
# --------------------
# Epoch 22
# train loss (loss per point): 9.723517290772275e-05
# test loss (loss per point): 9.56390202710671e-05
# --------------------
# Epoch 23
# train loss (loss per point): 9.709881826680391e-05
# test loss (loss per point): 9.577479280791163e-05
# --------------------
# Epoch 24
# train loss (loss per point): 9.697171146089727e-05
# test loss (loss per point): 9.592912052156163e-05
# --------------------
# Epoch 25
# train loss (loss per point): 9.685246660275028e-05
# test loss (loss per point): 9.610071690391978e-05
# --------------------
# Epoch 26
# train loss (loss per point): 9.67400174270919e-05
# test loss (loss per point): 9.628822931981816e-05
# --------------------
# Epoch 27
# train loss (loss per point): 9.663347531347832e-05
# test loss (loss per point): 9.649034948278294e-05
# --------------------
# Epoch 28
# train loss (loss per point): 9.653209520384987e-05
# test loss (loss per point): 9.67057881129234e-05
# --------------------
# Epoch 29
# train loss (loss per point): 9.643525420192708e-05
# test loss (loss per point): 9.693326701752234e-05
# --------------------
# Epoch 30
# train loss (loss per point): 9.634245028521152e-05
# test loss (loss per point): 9.717140802131573e-05
# --------------------
# Epoch 31
# train loss (loss per point): 9.625321888226144e-05
# test loss (loss per point): 9.741890006603635e-05
# --------------------
# Epoch 32
# train loss (loss per point): 9.616719390404351e-05
# test loss (loss per point): 9.767439150644251e-05
# --------------------
# Epoch 33
# train loss (loss per point): 9.608404938765663e-05
# test loss (loss per point): 9.793648555665752e-05
# --------------------
# Epoch 34
# train loss (loss per point): 9.600350474740596e-05
# test loss (loss per point): 9.820383651099694e-05
# --------------------
# Epoch 35
# train loss (loss per point): 9.592532665726352e-05
# test loss (loss per point): 9.84750323387205e-05
# --------------------
# Epoch 36
# train loss (loss per point): 9.584929011365835e-05
# test loss (loss per point): 9.874873584750913e-05
# --------------------
# Epoch 37
# train loss (loss per point): 9.577522866744945e-05
# test loss (loss per point): 9.902360212361935e-05
# --------------------
# Epoch 38
# train loss (loss per point): 9.570297299626659e-05
# test loss (loss per point): 9.929829575659922e-05
# --------------------
# Epoch 39
# train loss (loss per point): 9.563240926078659e-05
# test loss (loss per point): 9.95715593421819e-05
# --------------------
# Epoch 40
# train loss (loss per point): 9.556339667277767e-05
# test loss (loss per point): 9.984214992902312e-05
# --------------------
# Epoch 41
# train loss (loss per point): 9.549584824274829e-05
# test loss (loss per point): 0.00010010887881373467
# --------------------
# Epoch 42
# train loss (loss per point): 9.542968084520482e-05
# test loss (loss per point): 0.00010037062322201373
# --------------------
# Epoch 43
# train loss (loss per point): 9.536480550911833e-05
# test loss (loss per point): 0.0001006263098758677
# --------------------
# Epoch 44
# train loss (loss per point): 9.53011811175879e-05
# test loss (loss per point): 0.00010087495320476592
# --------------------
# Epoch 45
# train loss (loss per point): 9.523873623619054e-05
# test loss (loss per point): 0.00010111565930534432
# --------------------
# Epoch 46
# train loss (loss per point): 9.51774400520198e-05
# test loss (loss per point): 0.00010134756337806938
# --------------------
# Epoch 47
# train loss (loss per point): 9.511724193679525e-05
# test loss (loss per point): 0.00010156990614954104
# --------------------
# Epoch 48
# train loss (loss per point): 9.505812128252806e-05
# test loss (loss per point): 0.00010178204674153355
# --------------------
# Epoch 49
# train loss (loss per point): 9.500004499754373e-05
# test loss (loss per point): 0.00010198334407783589
# --------------------
# Epoch 50
# train loss (loss per point): 9.494298742093305e-05
# test loss (loss per point): 0.0001021733077490056
# --------------------
# Epoch 51
# train loss (loss per point): 9.488692635947719e-05
# test loss (loss per point): 0.00010235149684191055
# --------------------
# Epoch 52
# train loss (loss per point): 9.483184724887635e-05
# test loss (loss per point): 0.00010251755221132316
# --------------------
# Epoch 53
# train loss (loss per point): 9.477773582206127e-05
# test loss (loss per point): 0.00010267119786581722
# --------------------
# Epoch 54
# train loss (loss per point): 9.472457166919683e-05
# test loss (loss per point): 0.00010281222948462379
# --------------------
# Epoch 55
# train loss (loss per point): 9.467234300013553e-05
# test loss (loss per point): 0.00010294049580701861
# --------------------
# Epoch 56
# train loss (loss per point): 9.462103752934552e-05
# test loss (loss per point): 0.00010305593506160643
# --------------------
# Epoch 57
# train loss (loss per point): 9.457064416021743e-05
# test loss (loss per point): 0.00010315851477880765
# --------------------
# Epoch 58
# train loss (loss per point): 9.45211447616841e-05
# test loss (loss per point): 0.00010324828326702118
# --------------------
# Epoch 59
# train loss (loss per point): 9.447252258975455e-05
# test loss (loss per point): 0.00010332535931739171
# --------------------
# Epoch 60
# train loss (loss per point): 9.442477298781593e-05
# test loss (loss per point): 0.00010338986686868023
# --------------------
# Epoch 61
# train loss (loss per point): 9.437788287772143e-05
# test loss (loss per point): 0.00010344200271821651
# --------------------
# Epoch 62
# train loss (loss per point): 9.433182154564147e-05
# test loss (loss per point): 0.00010348198346185441
# --------------------
# Epoch 63
# train loss (loss per point): 9.428659711587936e-05
# test loss (loss per point): 0.00010351007241996474
# --------------------
# Epoch 64
# train loss (loss per point): 9.42421828376803e-05
# test loss (loss per point): 0.00010352653330888877
# --------------------
# Epoch 65
# train loss (loss per point): 9.419856206613018e-05
# test loss (loss per point): 0.00010353170983100525
# --------------------
# Epoch 66
# train loss (loss per point): 9.415571518400883e-05
# test loss (loss per point): 0.00010352592232643443
# --------------------
# Epoch 67
# train loss (loss per point): 9.411363803008769e-05
# test loss (loss per point): 0.00010350953033637433
# --------------------
# Epoch 68
# train loss (loss per point): 9.407230553791878e-05
# test loss (loss per point): 0.00010348293181115976
# --------------------
# Epoch 69
# train loss (loss per point): 9.403170235058728e-05
# test loss (loss per point): 0.00010344646372167128
# --------------------
# Epoch 70
# train loss (loss per point): 9.399181301210155e-05
# test loss (loss per point): 0.00010340057549440638
# --------------------
# Epoch 71
# train loss (loss per point): 9.39526243452379e-05
# test loss (loss per point): 0.0001033456223148878
# --------------------
# Epoch 72
# train loss (loss per point): 9.39141156429306e-05
# test loss (loss per point): 0.00010328198154298525
# --------------------
# Epoch 73
# train loss (loss per point): 9.387627719564641e-05
# test loss (loss per point): 0.0001032100998334029
# --------------------
# Epoch 74
# train loss (loss per point): 9.38390856212441e-05
# test loss (loss per point): 0.00010313036959288883
# --------------------
# Epoch 75
# train loss (loss per point): 9.3802525463732e-05
# test loss (loss per point): 0.00010304322638897364
# --------------------
# Epoch 76
# train loss (loss per point): 9.376658899511429e-05
# test loss (loss per point): 0.00010294897155519448
# --------------------
# Epoch 77
# train loss (loss per point): 9.37312610566299e-05
# test loss (loss per point): 0.00010284807827627781
# --------------------
# Epoch 78
# train loss (loss per point): 9.369652530059536e-05
# test loss (loss per point): 0.00010274089461027764
# --------------------
# Epoch 79
# train loss (loss per point): 9.366236399225098e-05
# test loss (loss per point): 0.00010262775832001551
# --------------------
# Epoch 80
# train loss (loss per point): 9.362876851190912e-05
# test loss (loss per point): 0.0001025090851744979
# --------------------
# Epoch 81
# train loss (loss per point): 9.359572786203724e-05
# test loss (loss per point): 0.00010238522402371983
# --------------------
# Epoch 82
# train loss (loss per point): 9.356322450602942e-05
# test loss (loss per point): 0.00010225645125507801
# --------------------
# Epoch 83
# train loss (loss per point): 9.353124784266062e-05
# test loss (loss per point): 0.00010212315175188135
# --------------------
# Epoch 84
# train loss (loss per point): 9.349979222454923e-05
# test loss (loss per point): 0.0001019856458542501
# --------------------
# Epoch 85
# train loss (loss per point): 9.34688455643172e-05
# test loss (loss per point): 0.00010184419450673218
# --------------------
# Epoch 86
# train loss (loss per point): 9.343839270320345e-05
# test loss (loss per point): 0.00010169916952561055
# --------------------
# Epoch 87
# train loss (loss per point): 9.340843235320868e-05
# test loss (loss per point): 0.00010155074355401555
# --------------------
# Epoch 88
# train loss (loss per point): 9.337895133710923e-05
# test loss (loss per point): 0.00010139927811299761
# --------------------
# Epoch 89
# train loss (loss per point): 9.334993697306578e-05
# test loss (loss per point): 0.00010124500524125942
# --------------------
# Epoch 90
# train loss (loss per point): 9.332139213430755e-05
# test loss (loss per point): 0.00010108813440718618
# --------------------
# Epoch 91
# train loss (loss per point): 9.329329948238236e-05
# test loss (loss per point): 0.00010092897525969512
# --------------------
# Epoch 92
# train loss (loss per point): 9.326565713482969e-05
# test loss (loss per point): 0.0001007676798514515
# --------------------
# Epoch 93
# train loss (loss per point): 9.323845003196534e-05
# test loss (loss per point): 0.00010060454199255324
# --------------------
# Epoch 94
# train loss (loss per point): 9.32116841184015e-05
# test loss (loss per point): 0.00010043970522230023
# --------------------
# Epoch 95
# train loss (loss per point): 9.318534165937849e-05
# test loss (loss per point): 0.00010027344869988254
# --------------------
# Epoch 96
# train loss (loss per point): 9.315943068012278e-05
# test loss (loss per point): 0.00010010589537413499
# --------------------
# Epoch 97
# train loss (loss per point): 9.313393423848963e-05
# test loss (loss per point): 9.993727569987832e-05
# --------------------
# Epoch 98
# train loss (loss per point): 9.310884381386828e-05
# test loss (loss per point): 9.97677682598001e-05
# --------------------
# Epoch 99
# train loss (loss per point): 9.30841613877961e-05
# test loss (loss per point): 9.9597549260765e-05

# %%
#load model to get stats
checkpoint = torch.load(f'./model_checkpoints/{task}_{model_descrip}_{data_descrip}_ckpt.pth')
checkpoint
# Out:
# {'model': OrderedDict([('linear.weight',
#                tensor([[-0.0071, -0.2621,  0.1031,  0.0008, -0.0231, -0.0126,  0.0084,  0.0723,
#                         -0.1082,  0.0613,  0.0400,  0.0698, -0.4440,  0.1453, -0.0870, -0.1070,
#                          0.0808,  0.1328,  0.2862]])),
#               ('linear.bias', tensor([0.3105]))]),
#  'epoch': 17,
#  'loss': 0.05603468022309244}

# %%
print(model)
# Out:
# LinearRegressionNN(
#   (linear): Linear(in_features=19, out_features=1, bias=True)
# )
